# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# Informações de conexão e caminho do certificado
username = 'root'
password = 'FomFAYykiMbEFBR15ahPbuPcPiaN1lq2'
host = '3il9oh.stackhero-network.com'
port = 6454  # Agora especificada corretamente como integer
database = 'BD_Anos_Consolidados'

# Configurações SSL
ssl_args = {
    'ssl': {
        'ca': 'C:\\Users\\RAYSON\\isrgrootx1.pem'  # Certifique-se de que o caminho é válido
    }
}

# Criar a engine de conexão com o banco de dados
engine = create_engine(
    f'mysql+pymysql://{username}:{password}@{host}:{port}/{database}',
    connect_args=ssl_args
)

# Especifique o nome da tabela que deseja acessar
nome_tabela = 'tconsolidada_2022_2023_2024_completa'  # Substitua pelo nome real da tabela

# Ler a tabela do banco de dados para um DataFrame do pandas
df = pd.read_sql_table(nome_tabela, con=engine)

# Exibir as primeiras linhas da tabela como verificação
df.head(5)

# Fechar a conexão se for explicitamente necessário
# engine.dispose()  # Apenas se precisão for notada para desalocar recursos
# Out:
#       season    status  odds_ft_home  odds_ft_empate  odds_ft_away Data_D_M_A  \
# 0  2021/2022  complete         10.00             6.0          1.25 2021-06-22
# 1  2021/2022  complete          1.37             4.7          7.50 2021-06-22
# 2  2021/2022  complete          1.45             4.0          6.50 2021-06-25
# 3  2021/2022  complete          1.67             3.8          5.25 2021-07-06
# 4  2021/2022  complete          1.33             4.5          7.00 2021-07-06
#
#            home_name              away_name  homeGoalCount  awayGoalCount  \
# 0       S.S. Folgore              Prishtina              0              2
# 1                 HB  Inter Club d'Escaldes              0              1
# 2          Prishtina  Inter Club d'Escaldes              2              0
# 3  Tallinna FC Flora             Hibernians              2              0
# 4          Fola Esch       Lincoln Red Imps              2              2
#
#    ...  Over15_FT Over25_FT Over35_FT  \
# 0  ...          1         0         0
# 1  ...          0         0         0
# 2  ...          1         0         0
# 3  ...          1         0         0
# 4  ...          1         1         1
#
#                                       liga                 nome_reduzido  \
# 0  Europe_UEFA_Champions_League_2022_21_22  Europe_UEFA_Champions_League
# 1  Europe_UEFA_Champions_League_2022_21_22  Europe_UEFA_Champions_League
# 2  Europe_UEFA_Champions_League_2022_21_22  Europe_UEFA_Champions_League
# 3  Europe_UEFA_Champions_League_2022_21_22  Europe_UEFA_Champions_League
# 4  Europe_UEFA_Champions_League_2022_21_22  Europe_UEFA_Champions_League
#
#                                         image_league  \
# 0  https://cdn.footystats.org/img/competitions/eu...
# 1  https://cdn.footystats.org/img/competitions/eu...
# 2  https://cdn.footystats.org/img/competitions/eu...
# 3  https://cdn.footystats.org/img/competitions/eu...
# 4  https://cdn.footystats.org/img/competitions/eu...
#
#               competitions_name        nome_todo_capitalizado  season_ano  \
# 0  europe-uefa-champions-league  Europe_UEFA_Champions_League        2022
# 1  europe-uefa-champions-league  Europe_UEFA_Champions_League        2022
# 2  europe-uefa-champions-league  Europe_UEFA_Champions_League        2022
# 3  europe-uefa-champions-league  Europe_UEFA_Champions_League        2022
# 4  europe-uefa-champions-league  Europe_UEFA_Champions_League        2022
#
#    Tipo_Torneio
# 0          Copa
# 1          Copa
# 2          Copa
# 3          Copa
# 4          Copa
#
# [5 rows x 29 columns]

# %%
df.to_excel('teste.xlsx',index=False,engine='openpyxl')
