# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# Informações de conexão e caminho do certificado
username = 'root'
password = 'FomFAYykiMbEFBR15ahPbuPcPiaN1lq2'
host = '3il9oh.stackhero-network.com'
port = 6454  # Agora especificada corretamente como integer
database = 'BD_Anos_Consolidados'

# Configurações SSL
ssl_args = {
    'ssl': {
        'ca': 'C:\\Users\\RAYSON\\isrgrootx1.pem'  # Certifique-se de que o caminho é válido
    }
}

# Criar a engine de conexão com o banco de dados
engine = create_engine(
    f'mysql+pymysql://{username}:{password}@{host}:{port}/{database}',
    connect_args=ssl_args
)

# Especifique o nome da tabela que deseja acessar
nome_tabela = 't_consolidada_2022_2023_2024'  # Substitua pelo nome real da tabela

# Ler a tabela do banco de dados para um DataFrame do pandas
df = pd.read_sql_table(nome_tabela, con=engine)

# Exibir as primeiras linhas da tabela como verificação
df.head(5)

# Fechar a conexão se for explicitamente necessário
# engine.dispose()  # Apenas se precisão for notada para desalocar recursos
# Out:
#      status  odds_ft_home  odds_ft_empate  odds_ft_away Data_D_M_A  \
# 0  complete          2.85            3.05          2.60 2021-07-23
# 1  complete          2.20            3.20          3.45 2021-07-25
# 2  complete          1.61            3.75          6.00 2021-07-25
# 3  complete          1.65            3.75          5.75 2021-07-24
# 4  complete          3.25            3.50          2.15 2021-07-24
#
#           home_name       away_name  homeGoalCount  awayGoalCount   date_unix  \
# 0            Rostov   Dinamo Moskva              0              2  1627059600
# 1    Krylya Sovetov   Akhmat Grozny              1              2  1627228800
# 2       CSKA Moskva             Ufa              1              0  1627232400
# 3  Lokomotiv Moskva    Arsenal Tula              3              1  1627146000
# 4       Rubin Kazan  Spartak Moskva              1              0  1627146000
#
#             Data_Hora                                    Fonte_Arquivo  \
# 0 2021-07-23 17:00:00  01_Russia_Russian_Premier_League_2022_21_22.csv
# 1 2021-07-25 16:00:00  01_Russia_Russian_Premier_League_2022_21_22.csv
# 2 2021-07-25 17:00:00  01_Russia_Russian_Premier_League_2022_21_22.csv
# 3 2021-07-24 17:00:00  01_Russia_Russian_Premier_League_2022_21_22.csv
# 4 2021-07-24 17:00:00  01_Russia_Russian_Premier_League_2022_21_22.csv
#
#                                           home_image  \
# 0  https://cdn.footystats.org/img/teams/russia-fk...
# 1  https://cdn.footystats.org/img/teams/russia-pf...
# 2  https://cdn.footystats.org/img/teams/russia-pf...
# 3  https://cdn.footystats.org/img/teams/russia-fk...
# 4  https://cdn.footystats.org/img/teams/russia-fk...
#
#                                           away_image  \
# 0  https://cdn.footystats.org/img/teams/russia-fk...
# 1  https://cdn.footystats.org/img/teams/russia-fk...
# 2  https://cdn.footystats.org/img/teams/russia-fk...
# 3  https://cdn.footystats.org/img/teams/russia-fk...
# 4  https://cdn.footystats.org/img/teams/russia-fk...
#
#                                        liga
# 0  Russia_Russian_Premier_League_2022_21_22
# 1  Russia_Russian_Premier_League_2022_21_22
# 2  Russia_Russian_Premier_League_2022_21_22
# 3  Russia_Russian_Premier_League_2022_21_22
# 4  Russia_Russian_Premier_League_2022_21_22
